# %% [markdown]
# relizar estas ejecuciones despues del notebook_real

# %%
df['Total Cost'].describe() #info de esa categoria

# %%
#Remover costos negativos
df = df[df['Total Cost'] >= 0]

# %%
#Recortar outliers extremos
#Usar percentiles:
q99 = df['Total Cost'].quantile(0.99)
df = df[df['Total Cost'] <= q99]

# %%
#Recortar outliers extremos
#Usar percentiles:
q99 = df['Total Cost'].quantile(0.99)
df = df[df['Total Cost'] <= q99]

# %%
#volvemos a entrenar usando esta columna de costos para regresión
y_cost = df['Total Cost Log']

# %%
print(len(X))
print(len(y_cost))
print(len(df))
#volver a ejecutar desde targets en adelante para que vuelva a tomar los nuevos registros ya limpios 
#y asi vuelva a tener los datos correctos.
